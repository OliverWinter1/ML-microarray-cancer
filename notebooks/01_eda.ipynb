# %%
import pandas as pd
import GEOparse

gse = GEOparse.get_GEO("GSE199633")
df = gse.pivot_samples("VALUE")

print(df.head())
# Out:
# 10-Jan-2026 11:04:27 DEBUG utils - Directory ./ already exists. Skipping.
# 10-Jan-2026 11:04:27 INFO GEOparse - Downloading ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE199nnn/GSE199633/soft/GSE199633_family.soft.gz to ./GSE199633_family.soft.gz
#   6%|▌         | 21.5M/348M [00:14<03:32, 1.61MB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 4
#       1 import pandas as pd
#       2 import GEOparse
# ----> 4 gse = GEOparse.get_GEO("GSE199633")
#       5 df = gse.pivot_samples("VALUE")
#       7 print(df.head())
#
# File c:\Users\ojwin\AppData\Local\Programs\Python\Python314\Lib\site-packages\GEOparse\GEOparse.py:96, in get_GEO(geo, filepath, destdir, how, annotate_gpl, geotype, include_data, silent, aspera, partial, open_kwargs)
#      93     logger.setLevel(100)  # More than critical
#      95 if filepath is None:
# ...
